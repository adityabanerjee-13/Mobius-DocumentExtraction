# %%
from logging import config
from marker.converters.pdf import PdfConverter
from marker.models import create_model_dict
# from marker.schema import BlockTypes

'''
-- page_range: List of page numbers to process. By default, all pages are processed. eg. [0,1,5-6,...]
-- ignore_TOC: Whether to ignore the page with Table of Contents page if detected. By default, False.
-- use_llm: Whether to use LLM to enhance the parsing of the document. By default, False.
-- ollama_base_url: Base URL for the Ollama LLM service. Default is 'http://localhost:11434'.
-- llm_service: The LLM service class to use. Default is 'marker.services.ollama.OllamaService'.
-- renderer: The format of the output document can be one of the following ('markdown|pageMarkdown|chunks|pageMarkdown+chunks'). Default is 'pageMarkdown+chunks'.
    - for 'markdown', the output dict with keys 'markdown', Dict[str, str].
    - for 'pageMarkdown', the output dict with keys 'page_renders' containing 'page numbers' as keys and 'markdown' or 'html' as values, Dict[int, Dict[str, str]].
    - for 'chunks', the output dict with keys 'chunks'containing 'page_id' as keys and 'html' as values for the text, Dict[str, Dict[str, Any]].
    - for 'pageMarkdown+chunks', the output dict with keys 'page_renders' and 'chunks'.
    Output json format contains: 
    --- 'page_structure': List[Dict[str, Any]]  (List of page-wise structure with text and blocks)
    --- 'page_renders'/'chunks' contain the information of the document.
'''

converter = PdfConverter(
    artifact_dict = create_model_dict(),
    config = {
        # "use_llm":True,
        # "ollama_base_url":"http://ollama-keda.mobiusdtaas.ai",
        # llm_service='marker.services.ollama.OllamaService',
        "page_range": [0, 4, 5],
        "ignore_TOC": True,
        "renderer": "markdown+chunks+pageMarkdown"
    }
)

# %%
document = converter.build_document("./PDFs/ISO_IEC_22237-1_2021(en) (1).pdf")
# Out:
# Recognizing layout: 100%|██████████| 1/1 [00:02<00:00,  2.27s/it]
# Resolved PageHeader = SectionHeader issue, height =  42.719914643093944
# Running OCR Error Detection: 100%|██████████| 1/1 [00:00<00:00,  4.31it/s]
# Detecting bboxes: 0it [00:00, ?it/s]

# %%
out_render = converter.render_document(document)

import json

# print("output keys:", out_render.keys())
# print(out_render)
print(json.dumps(out_render, indent=2))
# Out:
# {
#   "page_structure": {
#     "0": [
#       "/page/0/Text/0",
#       "/page/0/Picture/1",
#       "/page/0/Picture/2",
#       "/page/0/Text/3",
#       "/page/0/SectionHeader/4",
#       "/page/0/SectionHeader/5",
#       "/page/0/Text/6",
#       "/page/0/Text/7",
#       "/page/0/Picture/8",
#       "/page/0/Text/9",
#       "/page/0/Picture/10",
#       "/page/0/Text/11",
#       "/page/0/Text/12"
#     ],
#     "4": [
#       "/page/4/PageHeader/1",
#       "/page/4/SectionHeader/0",
#       "/page/4/SectionHeader/2",
#       "/page/4/Text/3",
#       "/page/4/Text/4",
#       "/page/4/Text/5",
#       "/page/4/Text/6",
#       "/page/4/Text/7",
#       "/page/4/Text/8",
#       "/page/4/Text/9",
#       "/page/4/Text/10",
#       "/page/4/ListGroup/209",
#       "/page/4/Text/16",
#       "/page/4/Text/17",
#       "/page/4/PageFooter/18",
#       "/page/4/PageFooter/19"
#     ],
#     "5": [
#       "/page/5/Text/0",
#       "/page/5/Text/1",
#       "/page/5/SectionHeader/2",
#       "/page/5/Text/3",
#       "/page/5/Text/4",
#       "/page/5/Text/5",
#       "/page/5/ListGroup/246",
#       "/page/5/Text/10",
#       "/page/5/Text/11",
#       "/page/5/Text/12",
#       "/page/5/ListGroup/247",
#       "/page/5/Text/17",
#       "/page/5/ListGroup/248",
#       "/page/5/PageFooter/23",
#       "/page/5/PageFooter/24"
#     ]
#   },
#   "markdown": "Licensed to Mobius Networks Pvt Ltd / Kotaru Ashwini (reddy.s@mobiusdtaas.ai) ISO Store Order: OP-871184 license #1/ Downloaded: 2025-02-11 Single user licence only, copying and networking prohibited.\n\n![](_page_0_Picture_1.jpeg)\n\n![](_page_0_Picture_2.jpeg)\n\nFirst edition 2021-10\n\n## **Information technology \u2014 Data centre facilities and infrastructures \u2014**\n\n# Part 1: **General concepts**\n\n*Technologie de l'information \u2014 Installation et infrastructures de centres de traitement de donn\u00e9es \u2014*\n\n*Partie 1: Concepts g\u00e9n\u00e9raux*\n\n![](_page_0_Picture_8.jpeg)\n\nwith your phone or click the link [Customer Feedback Form](https://go.iso.org/customer-feedback?token=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJzdGQiOiJJU08vSUVDIDIyMjM3LTE6MjAyMSIsImlzcyI6IklTTyJ9.vXuhGryIpqEeqORZt7Ew5KTOiKGYsFKYnMrw4OkUocs)\n\n![](_page_0_Picture_10.jpeg)\n\nReference number ISO/IEC 22237-1:2021(E)\n\n\u00a9 ISO/IEC 2021\n\n#### Licensed to Mobius Networks Pvt Ltd / Kotaru Ashwini (reddy.s@mobiusdtaas.ai) ISO Store Order: OP-871184 license #1/ Downloaded: 2025-02-11 Single user licence only, copying and networking prohibited.\n\n## **Foreword**\n\nISO (the International Organization for Standardization) and IEC (the International Electrotechnical Commission) form the specialized system for worldwide standardization. National bodies that are members of ISO or IEC participate in the development of International Standards through technical committees established by the respective organization to deal with particular fields of technical activity. ISO and IEC technical committees collaborate in fields of mutual interest. Other international organizations, governmental and non-governmental, in liaison with ISO and IEC, also take part in the work.\n\nThe procedures used to develop this document and those intended for its further maintenance are described in the ISO/IEC Directives, Part 1. In particular, the different approval criteria needed for the different types of document should be noted. This document was drafted in accordance with the editorial rules of the ISO/IEC Directives, Part 2 (see [www.iso.org/directives](http://www.iso.org/directives) or [www.iec.ch/members\\\\_experts/refdocs](http://www.iec.ch/members_experts/refdocs)).\n\nAttention is drawn to the possibility that some of the elements of this document may be the subject of patent rights. ISO and IEC shall not be held responsible for identifying any or all such patent rights. Details of any patent rights identified during the development of the document will be in the Introduction and/or on the ISO list of patent declarations received (see [www.iso.org/patents\\)](https://www.iso.org/iso-standards-and-patents.html) or the IEC list of patent declarations received (see [patents.iec.ch](https://patents.iec.ch)).\n\nAny trade name used in this document is information given for the convenience of users and does not constitute an endorsement.\n\nFor an explanation of the voluntary nature of standards, the meaning of ISO specific terms and expressions related to conformity assessment, as well as information about ISO's adherence to the World Trade Organization (WTO) principles in the Technical Barriers to Trade (TBT) see [www.iso.org/iso/foreword.html](http://www.iso.org/iso/foreword.html). In the IEC, see [www.iec.ch/understanding-standards.](https://www.iec.ch/understanding-standards)\n\nThis document was prepared by Joint Technical Committee ISO/IEC JTC 1, *Information technology*, Subcommittee SC 39, *Sustainability, IT & Data Centres*.\n\nThis first edition cancels and replaces the first edition (ISO/IEC TS 22237-1:2018), which has been technically revised.\n\nThe main changes are as follows:\n\n- reference to Key Performance Indicators of ISO/IEC 30134 series has been included;\n- [Clause](#page-19-0) 7 (Availability) has been revised;\n- the design processes [\\(Clause](#page-24-0) 8) and design principles [\\(Clause](#page-27-0) 9) hav ...
#   "images": {
#     "_page_0_Picture_1.jpeg": "...",
#     "_page_0_Picture_2.jpeg": "...",
#     "_page_0_Picture_8.jpeg": "...",
#     "_page_0_Picture_10.jpeg": "..."
#   },
#   "chunks": {
#     "/page/0/Text/0": {
#       "block_type": "0",
#       "page": 0,
#       "html": "<p block-type=\"Text\">Licensed to Mobius Networks Pvt Ltd / Kotaru Ashwini (reddy.s@mobiusdtaas.ai) ISO Store Order: OP-871184 license #1/ Downloaded: 2025-02-11 Single user licence only, copying and networking prohibited.</p>",
#       "bbox": [
#         153.71866631507874,
#         4.6467046197503805,
#         443.5006010532379,
#         35.62445068359375
#       ]
#     },
#     "/page/0/Picture/1": {
#       "block_type": "0",
#       "page": 1,
#       "html": "<p><img src='_page_0_Picture_1.jpeg'></p>",
#       "bbox": [
#         231.0816428810358,
#         33.05151484012604,
#         422.693115234375,
#         89.8072509765625
#       ]
#     },
#     "/page/0/Picture/2": {
#       "block_type": "0",
#       "page": 2,
#       "html": "<p><img src='_page_0_Picture_2.jpeg'></p>",
#       "bbox": [
#         453.7022973060608,
#         30.475509557127953,
#         562.4580477714538,
#         86.82489254772663
#       ]
#     },
#     "/page/0/Text/3": {
#       "block_type": "0",
#       "page": 3,
#       "html": "<p block-type=\"Text\">First edition 2021-10</p>",
#       "bbox": [
#         504.6322326660156,
#         122.88941442966461,
#         559.7047884464264,
#         148.106689453125
#       ]
#     },
#     "/page/0/SectionHeader/4": {
#       "block_type": "0",
#       "page": 4,
#       "html": "<h2><b>Information technology</b> <b>\u2014 Data centre </b> <b>facilities and infrastructures</b> <b>\u2014</b></h2>",
#       "bbox": [
#         239.3088412284851,
#         255.0792533159256,
#         560.5500197410583,
#         295.430908203125
#       ]
#     },
#     "/page/0/SectionHeader/5": {
#       "block_type": "0",
#       "page": 5,
#       "html": "<h1>Part 1: <b>General concepts</b></h1>",
#       "bbox": [
#         237.75186145305634,
#         301.0249511003494,
#         382.28863310813904,
#         342.8678023815155
#       ]
#     },
#     "/page/0/Text/6": {
#       "block_type": "0",
#       "page": 6,
#       "html": "<p block-type=\"Text\"><i>Technologie de l'information</i> <i>\u2014 Installation et infrastructures de </i> <i>centres de traitement de donn\u00e9es</i> <i>\u2014</i></p>",
#       "bbox": [
#         238.2188470363617,
#         352.8487138748169,
#         537.543479681015,
#         378.95389091968536
#       ]
#     },
#     "/page/0/Text/7": {
#       "block_type": "0",
#       "page": 7,
#       "html": "<p block-type=\"Text\"><i>Partie</i> <i>1: Concepts g\u00e9n\u00e9raux</i></p>",
#       "bbox": [
#         237.68200278282166,
#         383.97634094953537,
#         367.0206859111786,
#         397.4544910788536
#       ]
#     },
#     "/page/0/Picture/8": {
#       "block_type": "0",
#       "page": 8,
#       "html": "<p><img src='_page_0_Picture_8.jpeg'></p>",
#       "bbox": [
#         28.98855171352625,
#         621.7775872588157,
#         89.43008714169264,
#         687.242086327076
#       ]
#     },
#     "/page/0/Text/9": {
#       "block_type": "0",
#       "page": 9,
#       "html": "<p block-type=\"Text\">with your phone or click the link <a href=\"https://go.iso.org/customer-feedback?token=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJzdGQiOiJJU08vSUVDIDIyMjM3LTE6MjAyMSIsImlzcyI6IklTTyJ9.vXuhGryIpqEeqORZt7Ew5KTOiKGYsFKYnMrw4OkUocs\">Customer Feedback Form</a></p>",
#       "bbox": [
#         99.5,
#         631.7500321865082,
#         221.87476015090942,
#         676.534423828125
#       ]
#     },
#     "/page/0/Picture/10": {
#       "block_type": "0",
#       "page": 10,
#       "html": "<p><img src='_page_0_Picture_10.jpeg'></p>",
#       "bbox": [
#         230.46666965484619,
#         754.9936471700669,
#         365.46015014648435,
#         817.8459171533584
#       ]
#     },
#     "/page/0/Text/11": {
#       "block_type": "0",
#       "page": 11,
#       "html": "<p block-type=\"Text\">Reference number ISO/IEC 22237-1:2021(E)</p>",
#       "bbox": [
#         446.15221095085144,
#         755.3419657945633,
#         559.7685902118683,
#         780.2105865478516
#       ]
#     },
#     "/page/0/Text/12": {
#       "block_type": "0",
#       "page": 12,
#       "html": "<p block-type=\"Text\">\u00a9 ISO/IEC 2021</p>",
#       "bbox": [
#         489.581787109375,
#         805.22032558918,
#         558.427734375,
#         819.5251808166504
#       ]
#     },
#     "/page/4/PageHeader/1": {
#       "block_type": "4",
#       "page": 1,
#       "html": "",
#       "bbox": [
#         421.9908092021942,
#         34.594107285141945,
#         560.7724378108978,
#         47.93242985010147
#       ]
#     },
#     "/page/4/SectionHeader/0": {
#       "block_type": "4",
#       "page": 0,
#       "html": "<h4>Licensed to Mobius Networks Pvt Ltd / Kotaru Ashwini (reddy.s@mobiusdtaas.ai) ISO Store Order: OP-871184 license #1/ Downloaded: 2025-02-11 Single user licence only, copying and networking prohibited.</h4>",
#       "bbox": [
#         152.80208432674408,
#         5.291589390486479,
#         443.82021379470825,
#         37.32201515138149
#       ]
#     },
#     "/page/4/SectionHeader/2": {
#       "block_type": "4",
#       "page": 2,
#       "html": "<h2><b>Foreword</b></h2>",
#       "bbox": [
#         69.78223955631256,
#         81.78379298746586,
#         144.0279916524887,
#         101.78050856292248
#       ]
#     },
#     "/page/4/Text/3": {
#       "block_type": "4",
#       "page": 3,
#       "html": "<p block-type=\"Text\">ISO (the International Organization for Standardization) and IEC (the International Electrotechnical  Commission) form the specialized system for worldwide standardization. National bodies that are  members of ISO or IEC participate in the development of International Standards through technical  committees established by the respective organization to deal with particular fields of technical  activity. ISO and IEC technical committees collaborate in fields of mutual interest. Other international  organizations, governmental and non-governmental, in liaison with ISO and IEC, also take part in the  work.</p>",
#       "bbox": [
#         69.98352062702179,
#         115.65639781951904,
#         562.2345142364502,
#         204.1593017578125
#       ]
#     },
#     "/page/4/Text/4": {
#       "block_type": "4",
#       "page": 4,
#       "html": "<p block-type=\"Text\">The procedures used to develop this document and those intended for its further maintenance  are described in the ISO/IEC Directives, Part 1. In particular, the different approval criteria  needed for the different types of document should be noted. This document was drafted in  accordance with the editorial rules of the ISO/IEC Directives, Part 2 (see <a href=\"http://www.iso.org/directives\">www.iso.org/directives</a> or  <a href=\"http://www.iec.ch/members_experts/refdocs\">www.iec.ch/members_experts/refdocs</a>).</p>",
#       "bbox": [
#         69.67818868160248,
#         209.97894486784935,
#         562.4065942764282,
#         273.87176513671875
#       ]
#     },
#     "/page/4/Text/5": {
#       "block_type": "4",
#       "page": 5,
#       "html": "<p block-type=\"Text\">Attention is drawn to the possibility that some of the elements of this document may be the subject  of patent rights. ISO and IEC shall not be held responsible for identifying any or all such patent  rights. Details of any patent rights identified during the development of the document will be in the  Introduction and/or on the ISO list of patent declarations received (see<a href=\"https://www.iso.org/iso-standards-and-patents.html\"> www.iso.org/patents)</a> or the IEC  list of patent declarations received (see <a href=\"https://patents.iec.ch\">patents.iec.ch</a>).</p>",
#       "bbox": [
#         69.7238552570343,
#         280.47498536109924,
#         562.2785999774933,
#         343.5843505859375
#       ]
#     },
#     "/page/4/Text/6": {
#       "block_type": "4",
#       "page": 6,
#       "html": "<p block-type=\"Text\">Any trade name used in this document is information given for the convenience of users and does not  constitute an endorsement.</p>",
#       "bbox": [
#         69.19274818897247,
#         349.8921911716461,
#         562.8362970352173,
#         376.99700927734375
#       ]
#     },
#     "/page/4/Text/7": {
#       "block_type": "4",
#       "page": 7,
#       "html": "<p block-type=\"Text\">For an explanation of the voluntary nature of standards, the meaning of ISO specific terms and  expressions related to conformity assessment, as well as information about ISO's adherence to  the World Trade Organization (WTO) principles in the Technical Barriers to Trade (TBT) see  <a href=\"http://www.iso.org/iso/foreword.html\">www.iso.org/iso/foreword.html</a>. In the IEC, see <a href=\"https://www.iec.ch/understanding-standards\">www.iec.ch/understanding-standards.</a></p>",
#       "bbox": [
#         69.24349474906921,
#         383.9693398475647,
#         562.3655636310577,
#         434.60955810546875
#       ]
#     },
#     "/page/4/Text/8": {
#       "block_type": "4",
#       "page": 8,
#       "html": "<p block-type=\"Text\">This document was prepared by Joint Technical Committee ISO/IEC JTC 1, <i>Information technology</i>,  Subcommittee SC 39, <i>Sustainability, IT &amp; Data Centres</i>.</p>",
#       "bbox": [
#         69.39672911167145,
#         441.42770993709564,
#         561.8697500228882,
#         468.0221862792969
#       ]
#     },
#     "/page/4/Text/9": {
#       "block_type": "4",
#       "page": 9,
#       "html": "<p block-type=\"Text\">This first edition cancels and replaces the first edition (ISO/IEC TS 22237-1:2018), which has been  technically revised.</p>",
#       "bbox": [
#         68.94800305366516,
#         474.30759489536285,
#         561.602429151535,
#         501.4347839355469
#       ]
#     },
#     "/page/4/Text/10": {
#       "block_type": "4",
#       "page": 10,
#       "html": "<p block-type=\"Text\">The main changes are as follows:</p>",
#       "bbox": [
#         69.23409855365753,
#         507.89541923999786,
#         229.71589410305023,
#         522.7473754882812
#       ]
#     },
#     "/page/4/ListGroup/209": {
#       "block_type": "4",
#       "page": 209,
#       "html": "<p block-type=\"ListGroup\"><ul><li block-type=\"ListItem\"> reference to Key Performance Indicators of ISO/IEC 30134 series has been included;</li><li block-type=\"ListItem\"> <a href=\"#page-19-0\">Clause</a> 7 (Availability) has been revised;</li><li block-type=\"ListItem\"> the design processes <a href=\"#page-24-0\">(Clause</a> 8) and design principles <a href=\"#page-27-0\">(Clause</a> 9) have been moved from an annex to  the main body of the document;</li><li block-type=\"ListItem\"> the existing<a href=\"#page-30-0\"> Annex</a> A has been removed;</li><li block-type=\"ListItem\"> new <a href=\"#page-30-0\">Annexes</a> A and <a href=\"#page-35-0\">B</a> have been added.</li></ul></p>",
#       "bbox": [
#         68.82839250564575,
#         528.9703421592712,
#         561.7853441238403,
#         641.4103851318359
#       ]
#     },
#     "/page/4/Text/16": {
#       "block_type": "4",
#       "page": 16,
#       "html": "<p block-type=\"Text\">A list of all parts in the ISO/IEC 22237 series can be found on the ISO and IEC websites.</p>",
#       "bbox": [
#         69.86273777484894,
#         647.5358860492706,
#         483.1276431083679,
#         662.7229614257812
#       ]
#     },
#     "/page/4/Text/17": {
#       "block_type": "4",
#       "page": 17,
#       "html": "<p block-type=\"Text\">Any feedback or questions on this document should be directed to the user's national standards  body. A complete listing of these bodies can be found at <a href=\"http://www.iso.org/members.html\">www.iso.org/members.html </a>and  <a href=\"http://www.iec.ch/national-committees\">www.iec.ch/national-committees</a>.</p>",
#       "bbox": [
#         69.74941504001617,
#         669.0924044847488,
#         561.602180480957,
#         708.2355651855469
#       ]
#     },
#     "/page/4/PageFooter/18": {
#       "block_type": "4",
#       "page": 18,
#       "html": "",
#       "bbox": [
#         70.86609649658203,
#         805.0161142349243,
#         558.4262084960938,
#         818.5099773406982
#       ]
#     },
#     "/page/4/PageFooter/19": {
#       "block_type": "4",
#       "page": 19,
#       "html": "",
#       "bbox": [
#         552.8150858879089,
#         803.6585528850555,
#         559.7082343101501,
#         816.3436462879181
#       ]
#     },
#     "/page/5/Text/0": {
#       "block_type": "5",
#       "page": 0,
#       "html": "<p block-type=\"Text\">Licensed to Mobius Networks Pvt Ltd / Kotaru Ashwini (reddy.s@mobiusdtaas.ai) ISO Store Order: OP-871184 license #1/ Downloaded: 2025-02-11 Single user licence only, copying and networking prohibited.</p>",
#       "bbox": [
#         154.4199981689453,
#         4.093028649687767,
#         441.5880126953125,
#         37.016554437577724
#       ]
#     },
#     "/page/5/Text/1": {
#       "block_type": "5",
#       "page": 1,
#       "html": "<p block-type=\"Text\"><b>ISO/IEC 22237-1:2021(E)</b></p>",
#       "bbox": [
#         36.59154251217842,
#         35.14231991767883,
#         173.12237548828125,
#         48.29564651846886
#       ]
#     },
#     "/page/5/SectionHeader/2": {
#       "block_type": "5",
#       "page": 2,
#       "html": "<h3><b>Introduction</b></h3>",
#       "bbox": [
#         36.31109094619751,
#         82.9951216429472,
#         134.03271329402924,
#         101.67271919548512
#       ]
#     },
#     "/page/5/Text/3": {
#       "block_type": "5",
#       "page": 3,
#       "html": "<p block-type=\"Text\">The unrestricted access to internet-based information demanded by the information society has led to  an exponential growth of both internet traffic and the volume of stored/retrieved data. Data centres  are housing and supporting the information technology and network telecommunications equipment  for data processing, data storage and data transport. They are required both by network operators  (delivering those services to customer premises) and by enterprises within those customer premises.</p>",
#       "bbox": [
#         36.64972698688507,
#         116.40714681148529,
#         528.5137181282043,
#         179.95928955078125
#       ]
#     },
#     "/page/5/Text/4": {
#       "block_type": "5",
#       "page": 4,
#       "html": "<p block-type=\"Text\">Data centres need to provide modular, scalable and flexible facilities and infrastructures to easily  accommodate the rapidly changing requirements of the market. In addition, energy consumption  of data centres has become critical, both from an environmental point of view (reduction of carbon  footprint), and with respect to economic considerations (cost of energy) for the data centre operator.</p>",
#       "bbox": [
#         36.737099170684814,
#         186.6056906580925,
#         528.3217799663544,
#         237.57177734375
#       ]
#     },
#     "/page/5/Text/5": {
#       "block_type": "5",
#       "page": 5,
#       "html": "<p block-type=\"Text\">The implementation of data centres varies in terms of:</p>",
#       "bbox": [
#         36.13208365440369,
#         244.31469517946243,
#         295.1208565235138,
#         258.88446044921875
#       ]
#     },
#     "/page/5/ListGroup/246": {
#       "block_type": "5",
#       "page": 246,
#       "html": "<p block-type=\"ListGroup\"><ul><li block-type=\"ListItem\">a) purpose (enterprise, co-location, co-hosting or network operator facilities);</li><li block-type=\"ListItem\">b) security level;</li><li block-type=\"ListItem\">c) physical size; and</li><li block-type=\"ListItem\">d) accommodation (mobile, temporary and permanent constructions).</li></ul></p>",
#       "bbox": [
#         35.62702038884163,
#         265.2539874315262,
#         415.56732845306396,
#         344.134765625
#       ]
#     },
#     "/page/5/Text/10": {
#       "block_type": "5",
#       "page": 10,
#       "html": "<p block-type=\"Text\">NOTE Cloud services can be provided by all data centre types mentioned.</p>",
#       "bbox": [
#         35.32850468158722,
#         350.92501682043076,
#         377.27603816986084,
#         364.75628662109375
#       ]
#     },
#     "/page/5/Text/11": {
#       "block_type": "5",
#       "page": 11,
#       "html": "<p block-type=\"Text\">The needs of data centres also vary in terms of availability of service, the provision of security and  the objectives for energy efficiency. These needs and objectives influence the design of data centres in  terms of building construction, power distribution, environmental control, telecommunications cabling  and physical security. Effective management and operational information are required to monitor  achievement of the defined needs and objectives.</p>",
#       "bbox": [
#         35.613179206848145,
#         371.68363547325134,
#         529.2351469993591,
#         434.9103698730469
#       ]
#     },
#     "/page/5/Text/12": {
#       "block_type": "5",
#       "page": 12,
#       "html": "<p block-type=\"Text\">The ISO/IEC 22237 series specifies requirements and recommendations to support the various parties  involved in the design, planning, procurement, integration, installation, operation and maintenance of  facilities and infrastructures within data centres. These parties include:</p>",
#       "bbox": [
#         35.62518644332886,
#         441.2181285619736,
#         529.6267321109772,
#         480.4230041503906
#       ]
#     },
#     "/page/5/ListGroup/247": {
#       "block_type": "5",
#       "page": 247,
#       "html": "<p block-type=\"ListGroup\"><ul><li block-type=\"ListItem\">1) owners, operators, facility managers, ICT managers, project managers, main contractors;</li><li block-type=\"ListItem\">2) consultants, architects, building designers and builders, system/installation designers, auditors,  test and commissioning agents;</li><li block-type=\"ListItem\">3) suppliers of equipment; and</li><li block-type=\"ListItem\">4) installers, maintainers.</li></ul></p>",
#       "bbox": [
#         35.37718194723129,
#         487.30485212802887,
#         528.4048004150391,
#         577.7734069824219
#       ]
#     },
#     "/page/5/Text/17": {
#       "block_type": "5",
#       "page": 17,
#       "html": "<p block-type=\"Text\">At the time of publication of this document, the ISO/IEC 22237 series comprises the following  documents:</p>",
#       "bbox": [
#         36.01748204231262,
#         583.1668511629105,
#         527.1624066829681,
#         611.1859588623047
#       ]
#     },
#     "/page/5/ListGroup/248": {
#       "block_type": "5",
#       "page": 248,
#       "html": "<p block-type=\"ListGroup\"><ul><li block-type=\"ListItem\"> ISO/IEC 22237-1 (this document), <i>Information technology</i> <i> Data centre facilities and infrastructures </i> <i>\u2014 Part</i> <i>1: General concepts</i>;</li><li block-type=\"ListItem\"> ISO/IEC TS 22237-2, <i>Information technology</i> <i> Data centre facilities and infrastructures  Part</i> <i>2: </i> <i>Building construction</i>;</li><li block-type=\"ListItem\"> ISO/IEC 22237-3, <i>Information technology</i> <i> Data centre facilities and infrastructures</i> <i> Part</i> <i>3: Power </i> <i>distribution</i>;</li><li block-type=\"ListItem\"> ISO/IEC 22237-4, <i>Information technology</i> <i> Data centre facilities and infrastructures</i> <i> Part</i> <i>4: </i> <i>Environmental control</i>;</li><li block-type=\"ListItem\"> ISO/IEC TS 22237-5, <i>Information technology</i> <i> Data centre facilities and infrastructures</i> <i> Part</i> <i>5: </i> <i>Telecommunications cabling infrastructure</i>;</li></ul></p>",
#       "bbox": [
#         34.939690470695496,
#         616.4291619062424,
#         528.3128988742828,
#         778.2489700317383
#       ]
#     },
#     "/page/5/PageFooter/23": {
#       "block_type": "5",
#       "page": 23,
#       "html": "",
#       "bbox": [
#         36.850399017333984,
#         805.421826839447,
#         526.4898238182068,
#         818.5099773406982
#       ]
#     },
#     "/page/5/PageFooter/24": {
#       "block_type": "5",
#       "page": 24,
#       "html": "",
#       "bbox": [
#         35.922676384449005,
#         803.2149991989136,
#         46.311245024204254,
#         816.5590493679047
#       ]
#     }
#   },
#   "page_renders": {
#     "0": {
#       "markdown": "Licensed to Mobius Networks Pvt Ltd / Kotaru Ashwini (reddy.s@mobiusdtaas.ai) ISO Store Order: OP-871184 license #1/ Downloaded: 2025-02-11 Single user licence only, copying and networking prohibited.\n\n![](_page_0_Picture_1.jpeg)\n\n![](_page_0_Picture_2.jpeg)\n\nFirst edition 2021-10\n\n## **Information technology** **\u2014 Data centre** **facilities and infrastructures** **\u2014**\n\n# Part 1: **General concepts**\n\n*Technologie de l'information* *\u2014 Installation et infrastructures de*  *centres de traitement de donn\u00e9es* *\u2014*\n\n*Partie* *1: Concepts g\u00e9n\u00e9raux*\n\n![](_page_0_Picture_8.jpeg)\n\nwith your phone or click the link [Customer Feedback Form](https://go.iso.org/customer-feedback?token=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJzdGQiOiJJU08vSUVDIDIyMjM3LTE6MjAyMSIsImlzcyI6IklTTyJ9.vXuhGryIpqEeqORZt7Ew5KTOiKGYsFKYnMrw4OkUocs)\n\n![](_page_0_Picture_10.jpeg)\n\nReference number ISO/IEC 22237-1:2021(E)\n\n\u00a9 ISO/IEC 2021",
#       "html": "<p block-type=\"Text\">Licensed to Mobius Networks Pvt Ltd / Kotaru Ashwini (reddy.s@mobiusdtaas.ai) ISO Store Order: OP-871184 license #1/ Downloaded: 2025-02-11 Single user licence only, copying and networking prohibited.</p><p><img src=\"_page_0_Picture_1.jpeg\"/></p><p><img src=\"_page_0_Picture_2.jpeg\"/></p><p block-type=\"Text\">First edition 2021-10</p><h2><b>Information technology</b> <b>\u2014 Data centre </b> <b>facilities and infrastructures</b> <b>\u2014</b></h2><h1>Part 1: <b>General concepts</b></h1><p block-type=\"Text\"><i>Technologie de l'information</i> <i>\u2014 Installation et infrastructures de </i> <i>centres de traitement de donn\u00e9es</i> <i>\u2014</i></p><p block-type=\"Text\"><i>Partie</i> <i>1: Concepts g\u00e9n\u00e9raux</i></p><p><img src=\"_page_0_Picture_8.jpeg\"/></p><p block-type=\"Text\">with your phone or click the link <a href=\"https://go.iso.org/customer-feedback?token=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJzdGQiOiJJU08vSUVDIDIyMjM3LTE6MjAyMSIsImlzcyI6IklTTyJ9.vXuhGryIpqEeqORZt7Ew5KTOiKGYsFKYnMrw4OkUocs\">Customer Feedback Form</a></p><p><img src=\"_page_0_Picture_10.jpeg\"/></p><p block-type=\"Text\">Reference number ISO/IEC 22237-1:2021(E)</p><p block-type=\"Text\">\u00a9 ISO/IEC 2021</p>"
#     },
#     "4": {
#       "markdown": "#### Licensed to Mobius Networks Pvt Ltd / Kotaru Ashwini (reddy.s@mobiusdtaas.ai) ISO Store Order: OP-871184 license #1/ Downloaded: 2025-02-11 Single user licence only, copying and networking prohibited.\n\n## **Foreword**\n\nISO (the International Organization for Standardization) and IEC (the International Electrotechnical Commission) form the specialized system for worldwide standardization. National bodies that are members of ISO or IEC participate in the development of International Standards through technical committees established by the respective organization to deal with particular fields of technical activity. ISO and IEC technical committees collaborate in fields of mutual interest. Other international organizations, governmental and non-governmental, in liaison with ISO and IEC, also take part in the work.\n\nThe procedures used to develop this document and those intended for its further maintenance are described in the ISO/IEC Directives, Part 1. In particular, the different approval criteria needed for the different types of document should be noted. This document was drafted in accordance with the editorial rules of the ISO/IEC Directives, Part 2 (see [www.iso.org/directives](http://www.iso.org/directives) or [www.iec.ch/members\\\\_experts/refdocs](http://www.iec.ch/members_experts/refdocs)).\n\nAttention is drawn to the possibility that some of the elements of this document may be the subject of patent rights. ISO and IEC shall not be held responsible for identifying any or all such patent rights. Details of any patent rights identified during the development of the document will be in the Introduction and/or on the ISO list of patent declarations received (see [www.iso.org/patents\\)](https://www.iso.org/iso-standards-and-patents.html) or the IEC list of patent declarations received (see [patents.iec.ch](https://patents.iec.ch)).\n\nAny trade name used in this document is information given for the convenience of users and does not constitute an endorsement.\n\nFor an explanation of the voluntary nature of standards, the meaning of ISO specific terms and expressions related to conformity assessment, as well as information about ISO's adherence to the World Trade Organization (WTO) principles in the Technical Barriers to Trade (TBT) see [www.iso.org/iso/foreword.html](http://www.iso.org/iso/foreword.html). In the IEC, see [www.iec.ch/understanding-standards.](https://www.iec.ch/understanding-standards)\n\nThis document was prepared by Joint Technical Committee ISO/IEC JTC 1, *Information technology*, Subcommittee SC 39, *Sustainability, IT & Data Centres*.\n\nThis first edition cancels and replaces the first edition (ISO/IEC TS 22237-1:2018), which has been technically revised.\n\nThe main changes are as follows:\n\n- reference to Key Performance Indicators of ISO/IEC 30134 series has been included;\n- [Clause](#page-19-0) 7 (Availability) has been revised;\n- the design processes [\\(Clause](#page-24-0) 8) and design principles [\\(Clause](#page-27-0) 9) have been moved from an annex to the main body of the document;\n- the existing [Annex](#page-30-0) A has been removed;\n- new [Annexes](#page-30-0) A and [B](#page-35-0) have been added.\n\nA list of all parts in the ISO/IEC 22237 series can be found on the ISO and IEC websites.\n\nAny feedback or questions on this document should be directed to the user's national standards body. A complete listing of these bodies can be found at [www.iso.org/members.html](http://www.iso.org/members.html) and [www.iec.ch/national-committees](http://www.iec.ch/national-committees).",
#       "html": "<h4>Licensed to Mobius Networks Pvt Ltd / Kotaru Ashwini (reddy.s@mobiusdtaas.ai) ISO Store Order: OP-871184 license #1/ Downloaded: 2025-02-11 Single user licence only, copying and networking prohibited.</h4><h2><b>Foreword</b></h2><p block-type=\"Text\">ISO (the International Organization for Standardization) and IEC (the International Electrotechnical  Commission) form the specialized system for worldwide standardization. National bodies that are  members of ISO or IEC participate in the development of International Standards through technical  committees established by the respective organization to deal with particular fields of technical  activity. ISO and IEC technical committees collaborate in fields of mutual interest. Other international  organizations, governmental and non-governmental, in liaison with ISO and IEC, also take part in the  work.</p><p block-type=\"Text\">The procedures used to develop this document and those intended for its further maintenance  are described in the ISO/IEC Directives, Part 1. In particular, the different approval criteria  needed for the different types of document should be noted. This document was drafted in  accordance with the editorial rules of the ISO/IEC Directives, Part 2 (see <a href=\"http://www.iso.org/directives\">www.iso.org/directives</a> or  <a href=\"http://www.iec.ch/members_experts/refdocs\">www.iec.ch/members_experts/refdocs</a>).</p><p block-type=\"Text\">Attention is drawn to the possibility that some of the elements of this document may be the subject  of patent rights. ISO and IEC shall not be held responsible for identifying any or all such patent  rights. Details of any patent rights identified during the development of the document will be in the  Introduction and/or on the ISO list of patent declarations received (see<a href=\"https://www.iso.org/iso-standards-and-patents.html\"> www.iso.org/patents)</a> or the IEC  list of patent declarations received (see <a href=\"https://patents.iec.ch\">patents.iec.ch</a>).</p><p block-type=\"Text\">Any trade name used in this document is information given for the convenience of users and does not  constitute an endorsement.</p><p block-type=\"Text\">For an explanation of the voluntary nature of standards, the meaning of ISO specific terms and  expressions related to conformity assessment, as well as information about ISO's adherence to  the World Trade Organization (WTO) principles in the Technical Barriers to Trade (TBT) see  <a href=\"http://www.iso.org/iso/foreword.html\">www.iso.org/iso/foreword.html</a>. In the IEC, see <a href=\"https://www.iec.ch/understanding-standards\">www.iec.ch/understanding-standards.</a></p><p block-type=\"Text\">This document was prepared by Joint Technical Committee ISO/IEC JTC 1, <i>Information technology</i>,  Subcommittee SC 39, <i>Sustainability, IT &amp; Data Centres</i>.</p><p block-type=\"Text\">This first edition cancels and replaces the first edition (ISO/IEC TS 22237-1:2018), which has been  technically revised.</p><p block-type=\"Text\">The main changes are as follows:</p><p block-type=\"ListGroup\"><ul><li block-type=\"ListItem\"> reference to Key Performance Indicators of ISO/IEC 30134 series has been included;</li><li block-type=\"ListItem\"> <a href=\"#page-19-0\">Clause</a> 7 (Availability) has been revised;</li><li block-type=\"ListItem\"> the design processes <a href=\"#page-24-0\">(Clause</a> 8) and design principles <a href=\"#page-27-0\">(Clause</a> 9) have been moved from an annex to  the main body of the document;</li><li block-type=\"ListItem\"> the existing<a href=\"#page-30-0\"> Annex</a> A has been removed;</li><li block-type=\"ListItem\"> new <a href=\"#page-30-0\">Annexes</a> A and <a href=\"#page-35-0\">B</a> have been added.</li></ul></p><p block-type=\"Text\">A list of all parts in the ISO/IEC 22237 series can be found on the ISO and IEC websites.</p><p block-type=\"Text\">Any feedback or questions on this document should be directed to th ...
#     },
#     "5": {
#       "markdown": "Licensed to Mobius Networks Pvt Ltd / Kotaru Ashwini (reddy.s@mobiusdtaas.ai) ISO Store Order: OP-871184 license #1/ Downloaded: 2025-02-11 Single user licence only, copying and networking prohibited.\n\n**ISO/IEC 22237-1:2021(E)**\n\n### **Introduction**\n\nThe unrestricted access to internet-based information demanded by the information society has led to an exponential growth of both internet traffic and the volume of stored/retrieved data. Data centres are housing and supporting the information technology and network telecommunications equipment for data processing, data storage and data transport. They are required both by network operators (delivering those services to customer premises) and by enterprises within those customer premises.\n\nData centres need to provide modular, scalable and flexible facilities and infrastructures to easily accommodate the rapidly changing requirements of the market. In addition, energy consumption of data centres has become critical, both from an environmental point of view (reduction of carbon footprint), and with respect to economic considerations (cost of energy) for the data centre operator.\n\nThe implementation of data centres varies in terms of:\n\n- a) purpose (enterprise, co-location, co-hosting or network operator facilities);\n- b) security level;\n- c) physical size; and\n- d) accommodation (mobile, temporary and permanent constructions).\n\nNOTE Cloud services can be provided by all data centre types mentioned.\n\nThe needs of data centres also vary in terms of availability of service, the provision of security and the objectives for energy efficiency. These needs and objectives influence the design of data centres in terms of building construction, power distribution, environmental control, telecommunications cabling and physical security. Effective management and operational information are required to monitor achievement of the defined needs and objectives.\n\nThe ISO/IEC 22237 series specifies requirements and recommendations to support the various parties involved in the design, planning, procurement, integration, installation, operation and maintenance of facilities and infrastructures within data centres. These parties include:\n\n- 1) owners, operators, facility managers, ICT managers, project managers, main contractors;\n- 2) consultants, architects, building designers and builders, system/installation designers, auditors, test and commissioning agents;\n- 3) suppliers of equipment; and\n- 4) installers, maintainers.\n\nAt the time of publication of this document, the ISO/IEC 22237 series comprises the following documents:\n\n- ISO/IEC 22237-1 (this document), *Information technology*  *Data centre facilities and infrastructures*  *\u2014 Part* *1: General concepts*;\n- ISO/IEC TS 22237-2, *Information technology*  *Data centre facilities and infrastructures Part* *2:*  *Building construction*;\n- ISO/IEC 22237-3, *Information technology*  *Data centre facilities and infrastructures*  *Part* *3: Power*  *distribution*;\n- ISO/IEC 22237-4, *Information technology*  *Data centre facilities and infrastructures*  *Part* *4:*  *Environmental control*;\n- ISO/IEC TS 22237-5, *Information technology*  *Data centre facilities and infrastructures*  *Part* *5:*  *Telecommunications cabling infrastructure*;",
#       "html": "<p block-type=\"Text\">Licensed to Mobius Networks Pvt Ltd / Kotaru Ashwini (reddy.s@mobiusdtaas.ai) ISO Store Order: OP-871184 license #1/ Downloaded: 2025-02-11 Single user licence only, copying and networking prohibited.</p><p block-type=\"Text\"><b>ISO/IEC 22237-1:2021(E)</b></p><h3><b>Introduction</b></h3><p block-type=\"Text\">The unrestricted access to internet-based information demanded by the information society has led to  an exponential growth of both internet traffic and the volume of stored/retrieved data. Data centres  are housing and supporting the information technology and network telecommunications equipment  for data processing, data storage and data transport. They are required both by network operators  (delivering those services to customer premises) and by enterprises within those customer premises.</p><p block-type=\"Text\">Data centres need to provide modular, scalable and flexible facilities and infrastructures to easily  accommodate the rapidly changing requirements of the market. In addition, energy consumption  of data centres has become critical, both from an environmental point of view (reduction of carbon  footprint), and with respect to economic considerations (cost of energy) for the data centre operator.</p><p block-type=\"Text\">The implementation of data centres varies in terms of:</p><p block-type=\"ListGroup\"><ul><li block-type=\"ListItem\">a) purpose (enterprise, co-location, co-hosting or network operator facilities);</li><li block-type=\"ListItem\">b) security level;</li><li block-type=\"ListItem\">c) physical size; and</li><li block-type=\"ListItem\">d) accommodation (mobile, temporary and permanent constructions).</li></ul></p><p block-type=\"Text\">NOTE Cloud services can be provided by all data centre types mentioned.</p><p block-type=\"Text\">The needs of data centres also vary in terms of availability of service, the provision of security and  the objectives for energy efficiency. These needs and objectives influence the design of data centres in  terms of building construction, power distribution, environmental control, telecommunications cabling  and physical security. Effective management and operational information are required to monitor  achievement of the defined needs and objectives.</p><p block-type=\"Text\">The ISO/IEC 22237 series specifies requirements and recommendations to support the various parties  involved in the design, planning, procurement, integration, installation, operation and maintenance of  facilities and infrastructures within data centres. These parties include:</p><p block-type=\"ListGroup\"><ul><li block-type=\"ListItem\">1) owners, operators, facility managers, ICT managers, project managers, main contractors;</li><li block-type=\"ListItem\">2) consultants, architects, building designers and builders, system/installation designers, auditors,  test and commissioning agents;</li><li block-type=\"ListItem\">3) suppliers of equipment; and</li><li block-type=\"ListItem\">4) installers, maintainers.</li></ul></p><p block-type=\"Text\">At the time of publication of this document, the ISO/IEC 22237 series comprises the following  documents:</p><p block-type=\"ListGroup\"><ul><li block-type=\"ListItem\"> ISO/IEC 22237-1 (this document), <i>Information technology</i> <i> Data centre facilities and infrastructures </i> <i>\u2014 Part</i> <i>1: General concepts</i>;</li><li block-type=\"ListItem\"> ISO/IEC TS 22237-2, <i>Information technology</i> <i> Data centre facilities and infrastructures  Part</i> <i>2: </i> <i>Building construction</i>;</li><li block-type=\"ListItem\"> ISO/IEC 22237-3, <i>Information technology</i> <i> Data centre facilities and infrastructures</i> <i> Part</i> <i>3: Power </i> <i>distribution</i>;</li><li block-type=\"ListItem\"> ISO/IEC 22237-4, <i>Information technology</i> <i> Data centre facilities and infrastructures</i> <i> Part</i> <i>4: </i> <i>Environmental control</i>;</li><li block-type=\"ListItem\"> ISO/IEC  ...
#     }
#   },
#   "metadata": {
#     "table_of_contents": [
#       {
#         "title": "Information technology \u2014 Data centre \nfacilities and infrastructures \u2014",
#         "heading_level": null,
#         "page_id": 0,
#         "polygon": [
#           [
#             239.3088412284851,
#             255.0792533159256
#           ],
#           [
#             560.5500197410583,
#             255.0792533159256
#           ],
#           [
#             560.5500197410583,
#             295.430908203125
#           ],
#           [
#             239.3088412284851,
#             295.430908203125
#           ]
#         ]
#       },
#       {
#         "title": "Part 1:\nGeneral concepts",
#         "heading_level": null,
#         "page_id": 0,
#         "polygon": [
#           [
#             237.75186145305634,
#             301.0249511003494
#           ],
#           [
#             382.28863310813904,
#             301.0249511003494
#           ],
#           [
#             382.28863310813904,
#             342.8678023815155
#           ],
#           [
#             237.75186145305634,
#             342.8678023815155
#           ]
#         ]
#       },
#       {
#         "title": "Licensed to Mobius Networks Pvt Ltd / Kotaru Ashwini (reddy.s@mobiusdtaas.ai)\nISO Store Order: OP-871184 license #1/ Downloaded: 2025-02-11\nSingle user licence only, copying and networking prohibited.",
#         "heading_level": null,
#         "page_id": 4,
#         "polygon": [
#           [
#             152.80208432674408,
#             5.291589390486479
#           ],
#           [
#             443.82021379470825,
#             5.291589390486479
#           ],
#           [
#             443.82021379470825,
#             37.32201515138149
#           ],
#           [
#             152.80208432674408,
#             37.32201515138149
#           ]
#         ]
#       },
#       {
#         "title": "Foreword",
#         "heading_level": null,
#         "page_id": 4,
#         "polygon": [
#           [
#             69.78223955631256,
#             83.42832423746586
#           ],
#           [
#             144.0279916524887,
#             81.78379298746586
#           ],
#           [
#             144.0279916524887,
#             101.14910888671875
#           ],
#           [
#             69.78223955631256,
#             101.78050856292248
#           ]
#         ]
#       },
#       {
#         "title": "Introduction",
#         "heading_level": null,
#         "page_id": 5,
#         "polygon": [
#           [
#             36.31109094619751,
#             82.9951216429472
#           ],
#           [
#             134.03271329402924,
#             82.9951216429472
#           ],
#           [
#             134.03271329402924,
#             101.67271919548512
#           ],
#           [
#             36.31109094619751,
#             101.67271919548512
#           ]
#         ]
#       }
#     ],
#     "page_stats": [
#       {
#         "page_id": 0,
#         "text_extraction_method": "pdftext",
#         "block_counts": [
#           [
#             "Span",
#             53
#           ],
#           [
#             "Line",
#             21
#           ],
#           [
#             "Text",
#             7
#           ],
#           [
#             "Picture",
#             4
#           ],
#           [
#             "SectionHeader",
#             2
#           ]
#         ],
#         "block_metadata": {
#           "llm_request_count": 0,
#           "llm_error_count": 0,
#           "llm_tokens_used": 0,
#           "previous_text": "",
#           "previous_type": "",
#           "previous_order": 0
#         }
#       },
#       {
#         "page_id": 4,
#         "text_extraction_method": "pdftext",
#         "block_counts": [
#           [
#             "Span",
#             145
#           ],
#           [
#             "Line",
#             44
#           ],
#           [
#             "Text",
#             10
#           ],
#           [
#             "ListItem",
#             5
#           ],
#           [
#             "SectionHeader",
#             2
#           ],
#           [
#             "PageFooter",
#             2
#           ],
#           [
#             "PageHeader",
#             1
#           ],
#           [
#             "ListGroup",
#             1
#           ]
#         ],
#         "block_metadata": {
#           "llm_request_count": 0,
#           "llm_error_count": 0,
#           "llm_tokens_used": 0,
#           "previous_text": "",
#           "previous_type": "",
#           "previous_order": 0
#         }
#       },
#       {
#         "page_id": 5,
#         "text_extraction_method": "pdftext",
#         "block_counts": [
#           [
#             "Span",
#             175
#           ],
#           [
#             "Line",
#             46
#           ],
#           [
#             "ListItem",
#             13
#           ],
#           [
#             "Text",
#             9
#           ],
#           [
#             "ListGroup",
#             3
#           ],
#           [
#             "PageFooter",
#             2
#           ],
#           [
#             "SectionHeader",
#             1
#           ]
#         ],
#         "block_metadata": {
#           "llm_request_count": 0,
#           "llm_error_count": 0,
#           "llm_tokens_used": 0,
#           "previous_text": "",
#           "previous_type": "",
#           "previous_order": 0
#         }
#       }
#     ],
#     "debug_data_path": "debug_data\\ISO_IEC_22237-1_2021(en) (1)"
#   }
# }

# %%
import json
from textwrap import indent

# assuming your dictionary is stored in a variable called `doc_data`

def display_document_info(doc_data: dict):
    print("=" * 80)
    print("📘 Document Overview")
    print("=" * 80)

    # --- Licensed Info / Metadata ---
    if "chunks" in doc_data and "/page/0/Text/0" in doc_data["chunks"]:
        license_info = doc_data["chunks"]["/page/0/Text/0"]["html"]
        print("\n🔒 License Information:")
        print(indent(license_info, "  "))

    # --- Table of Contents ---
    if "metadata" in doc_data and "table_of_contents" in doc_data["metadata"]:
        print("\n📑 Table of Contents:")
        for item in doc_data["metadata"]["table_of_contents"]:
            print(f"  - {item['title']} (page {item['page_id']})")

    # --- Page Structure ---
    if "page_structure" in doc_data:
        print("\n📄 Page Structure:")
        for page, elements in doc_data["page_structure"].items():
            print(f"\n  Page {page}:")
            for elem in elements:
                print(f"    • {elem}")

    # --- Chunk Text (sample) ---
    if "chunks" in doc_data:
        print("\n📝 Extracted Chunks (sample):")
        for key, value in list(doc_data["chunks"].items()):  # limit for brevity
            text = value.get("html", "").strip()
            print(f"  - {key}: {text[:100]}{'...' if len(text) > 100 else ''}")

    # --- Page Stats ---
    if "metadata" in doc_data and "page_stats" in doc_data["metadata"]:
        print("\n📊 Page Statistics:")
        for stat in doc_data["metadata"]["page_stats"]:
            page_id = stat["page_id"]
            counts = ", ".join([f"{typ}={count}" for typ, count in stat["block_counts"]])
            print(f"  Page {page_id}: {counts}")

    print("\n✅ Display Complete")
    print("=" * 80)


display_document_info(out_render)
# Out:
# ================================================================================
# 📘 Document Overview
# ================================================================================
#
# 🔒 License Information:
#   <p block-type="Text">Licensed to Mobius Networks Pvt Ltd / Kotaru Ashwini (reddy.s@mobiusdtaas.ai) ISO Store Order: OP-871184 license #1/ Downloaded: 2025-02-11 Single user licence only, copying and networking prohibited.</p>
#
# 📑 Table of Contents:
#   - Information technology — Data centre
# facilities and infrastructures — (page 0)
#   - Part 1:
# General concepts (page 0)
#   - Licensed to Mobius Networks Pvt Ltd / Kotaru Ashwini (reddy.s@mobiusdtaas.ai)
# ISO Store Order: OP-871184 license #1/ Downloaded: 2025-02-11
# Single user licence only, copying and networking prohibited. (page 4)
#   - Foreword (page 4)
#   - Introduction (page 5)
#
# 📄 Page Structure:
#
#   Page 0:
#     • /page/0/Text/0
#     • /page/0/Picture/1
#     • /page/0/Picture/2
#     • /page/0/Text/3
#     • /page/0/SectionHeader/4
#     • /page/0/SectionHeader/5
#     • /page/0/Text/6
#     • /page/0/Text/7
#     • /page/0/Picture/8
#     • /page/0/Text/9
#     • /page/0/Picture/10
#     • /page/0/Text/11
#     • /page/0/Text/12
#
#   Page 4:
#     • /page/4/PageHeader/1
#     • /page/4/SectionHeader/0
#     • /page/4/SectionHeader/2
#     • /page/4/Text/3
#     • /page/4/Text/4
#     • /page/4/Text/5
#     • /page/4/Text/6
#     • /page/4/Text/7
#     • /page/4/Text/8
#     • /page/4/Text/9
#     • /page/4/Text/10
#     • /page/4/ListGroup/209
#     • /page/4/Text/16
#     • /page/4/Text/17
#     • /page/4/PageFooter/18
#     • /page/4/PageFooter/19
#
#   Page 5:
#     • /page/5/Text/0
#     • /page/5/Text/1
#     • /page/5/SectionHeader/2
#     • /page/5/Text/3
#     • /page/5/Text/4
#     • /page/5/Text/5
#     • /page/5/ListGroup/246
#     • /page/5/Text/10
#     • /page/5/Text/11
#     • /page/5/Text/12
#     • /page/5/ListGroup/247
#     • /page/5/Text/17
#     • /page/5/ListGroup/248
#     • /page/5/PageFooter/23
#     • /page/5/PageFooter/24
#
# 📝 Extracted Chunks (sample):
#   - /page/0/Text/0: <p block-type="Text">Licensed to Mobius Networks Pvt Ltd / Kotaru Ashwini (reddy.s@mobiusdtaas.ai) I...
#   - /page/0/Picture/1: <p><img src='_page_0_Picture_1.jpeg'></p>
#   - /page/0/Picture/2: <p><img src='_page_0_Picture_2.jpeg'></p>
#   - /page/0/Text/3: <p block-type="Text">First edition 2021-10</p>
#   - /page/0/SectionHeader/4: <h2><b>Information technology</b> <b>— Data centre </b> <b>facilities and infrastructures</b> <b>—</...
#   - /page/0/SectionHeader/5: <h1>Part 1: <b>General concepts</b></h1>
#   - /page/0/Text/6: <p block-type="Text"><i>Technologie de l'information</i> <i>— Installation et infrastructures de </i...
#   - /page/0/Text/7: <p block-type="Text"><i>Partie</i> <i>1: Concepts généraux</i></p>
#   - /page/0/Picture/8: <p><img src='_page_0_Picture_8.jpeg'></p>
#   - /page/0/Text/9: <p block-type="Text">with your phone or click the link <a href="https://go.iso.org/customer-feedback...
#   - /page/0/Picture/10: <p><img src='_page_0_Picture_10.jpeg'></p>
#   - /page/0/Text/11: <p block-type="Text">Reference number ISO/IEC 22237-1:2021(E)</p>
#   - /page/0/Text/12: <p block-type="Text">© ISO/IEC 2021</p>
#   - /page/4/PageHeader/1:
#   - /page/4/SectionHeader/0: <h4>Licensed to Mobius Networks Pvt Ltd / Kotaru Ashwini (reddy.s@mobiusdtaas.ai) ISO Store Order: O...
#   - /page/4/SectionHeader/2: <h2><b>Foreword</b></h2>
#   - /page/4/Text/3: <p block-type="Text">ISO (the International Organization for Standardization) and IEC (the Internati...
#   - /page/4/Text/4: <p block-type="Text">The procedures used to develop this document and those intended for its further...
#   - /page/4/Text/5: <p block-type="Text">Attention is drawn to the possibility that some of the elements of this documen...
#   - /page/4/Text/6: <p block-type="Text">Any trade name used in this document is information given for the convenience o...
#   - /page/4/Text/7: <p block-type="Text">For an explanation of the voluntary nature of standards, the meaning of ISO spe...
#   - /page/4/Text/8: <p block-type="Text">This document was prepared by Joint Technical Committee ISO/IEC JTC 1, <i>Infor...
#   - /page/4/Text/9: <p block-type="Text">This first edition cancels and replaces the first edition (ISO/IEC TS 22237-1:2...
#   - /page/4/Text/10: <p block-type="Text">The main changes are as follows:</p>
#   - /page/4/ListGroup/209: <p block-type="ListGroup"><ul><li block-type="ListItem"> reference to Key Performance Indicators of ...
#   - /page/4/Text/16: <p block-type="Text">A list of all parts in the ISO/IEC 22237 series can be found on the ISO and IEC...
#   - /page/4/Text/17: <p block-type="Text">Any feedback or questions on this document should be directed to the user's nat...
#   - /page/4/PageFooter/18:
#   - /page/4/PageFooter/19:
#   - /page/5/Text/0: <p block-type="Text">Licensed to Mobius Networks Pvt Ltd / Kotaru Ashwini (reddy.s@mobiusdtaas.ai) I...
#   - /page/5/Text/1: <p block-type="Text"><b>ISO/IEC 22237-1:2021(E)</b></p>
#   - /page/5/SectionHeader/2: <h3><b>Introduction</b></h3>
#   - /page/5/Text/3: <p block-type="Text">The unrestricted access to internet-based information demanded by the informati...
#   - /page/5/Text/4: <p block-type="Text">Data centres need to provide modular, scalable and flexible facilities and infr...
#   - /page/5/Text/5: <p block-type="Text">The implementation of data centres varies in terms of:</p>
#   - /page/5/ListGroup/246: <p block-type="ListGroup"><ul><li block-type="ListItem">a) purpose (enterprise, co-location, co-host...
#   - /page/5/Text/10: <p block-type="Text">NOTE Cloud services can be provided by all data centre types mentioned.</p>
#   - /page/5/Text/11: <p block-type="Text">The needs of data centres also vary in terms of availability of service, the pr...
#   - /page/5/Text/12: <p block-type="Text">The ISO/IEC 22237 series specifies requirements and recommendations to support ...
#   - /page/5/ListGroup/247: <p block-type="ListGroup"><ul><li block-type="ListItem">1) owners, operators, facility managers, ICT...
#   - /page/5/Text/17: <p block-type="Text">At the time of publication of this document, the ISO/IEC 22237 series comprises...
#   - /page/5/ListGroup/248: <p block-type="ListGroup"><ul><li block-type="ListItem"> ISO/IEC 22237-1 (this document), <i>Informa...
#   - /page/5/PageFooter/23:
#   - /page/5/PageFooter/24:
#
# 📊 Page Statistics:
#   Page 0: Span=53, Line=21, Text=7, Picture=4, SectionHeader=2
#   Page 4: Span=145, Line=44, Text=10, ListItem=5, SectionHeader=2, PageFooter=2, PageHeader=1, ListGroup=1
#   Page 5: Span=175, Line=46, ListItem=13, Text=9, ListGroup=3, PageFooter=2, SectionHeader=1
#
# ✅ Display Complete
# ================================================================================
